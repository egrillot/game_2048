# %% [markdown]
# # Naive (test) Monte Carlo Tree Search

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from game_2048.agent.alpha_zero.NaiveAgent import NaiveAgent
from game_2048.agent.alpha_zero.training import train_deep_mcts

agent = NaiveAgent()

# %%
train_deep_mcts(
    num_episodes=10,
    num_mcts_simulations=500,
    model=agent,
    saving_path='../game_2048/models/'
)
# Out:
# Episode 1:
#
#  333/4000 [=>............................] - estimated time remaining: 22:54 - max tile seen: 512
# --- max tile reached: 512 --- move count: 333 --- average loss: None
#
# #########
#
#
# Episode 2:
#
#  180/4000 [>.............................] - estimated time remaining: 21:57 - max tile seen: 128
# --- max tile reached: 128 --- move count: 180 --- average loss: None
#
# #########
#
#
# Episode 3:
#
#  205/4000 [>.............................] - estimated time remaining: 21:37 - max tile seen: 128
# --- max tile reached: 128 --- move count: 205 --- average loss: None
#
# #########
#
#
# Episode 4:
#
#  148/4000 [>.............................] - estimated time remaining: 21:02 - max tile seen: 128
# --- max tile reached: 128 --- move count: 148 --- average loss: None
#
# #########
#
#
# Episode 5:
#
#  309/4000 [=>............................] - estimated time remaining: 22:04 - max tile seen: 256
# ...
