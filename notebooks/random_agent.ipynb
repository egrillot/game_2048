# %% [markdown]
# # Random Agent

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from game_2048.env import env_2048
from game_2048.agent import RandomAgent, espilon_greedy_search
from game_2048.utils import exponential_espilon_decrease

env = env_2048()
agent = RandomAgent('random agent')

# %%
espilon_greedy_search(
    agent=agent,
    env=env,
    max_iteration=1000,
    epochs=100,
    epsilon=0.9,
    decrease_function=exponential_espilon_decrease(epsilon_min=0.01, exponential_decay=50000),
    verbose=1
)
# Out:
# Training the agent random agent
# with parameters : Uniform
#
# Epsilon greedy search parameters : max_iteration=1000, epochs=100 and epsilon=0.9.
#
# Epoch : 1/100, epsilon = 0.9
# 1000/1000 [==============================] - 0s 82us/iteration - cumulate rewards: -3668.0 - max reached: 128 - sucessfull actions count: 87 - failed actions count: 46 - explore count: 111 - exploit count: 22 - model loss: None
#
# Epoch ended at 133 iterations - Exploit deflected to explore count : 0 - Exploit count : 22.
#
# ###################
#
# Epoch : 2/100, epsilon = 0.756698480231485
# 1000/1000 [==============================] - 0s 71us/iteration - cumulate rewards: -2960.0 - max reached: 256 - sucessfull actions count: 96 - failed actions count: 65 - explore count: 91 - exploit count: 70 - model loss: None
#
# Epoch ended at 161 iterations - Exploit deflected to explore count : 0 - Exploit count : 70.
#
# ###################
#
# Epoch : 3/100, epsilon = 0.38829013825883135
# ...
